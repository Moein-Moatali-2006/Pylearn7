# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("input\watermelon.png")
image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

# %%
H,S,V = cv2.split(image)

# %%
# Green 60 degree
# Blue 120 degree
H_new = H.copy().astype(np.float32)

for i in range(H.shape[0]):
    for j in range(H.shape[1]):
        if 30 < H[i,j] < 80: #green
            H_new[i,j]-=50

        if H_new[i,j] < 0:
            H_new[i,j]+=180

        if  H[i,j] < 15 or H[i,j] > 165:
            H_new[i,j]+=60

H_new=H_new.astype(np.int8)

# %%
result = cv2.merge((H_new,S,V))
result = cv2.cvtColor(result,cv2.COLOR_HSV2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 result = cv2.merge((H_new,S,V))
#       2 result = cv2.cvtColor(result,cv2.COLOR_HSV2RGB)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\merge.dispatch.cpp:130: error: (-215:Assertion failed) mv[i].size == mv[0].size && mv[i].depth() == depth in function 'cv::merge'

# %%
plt.imshow(result)
plt.show()
