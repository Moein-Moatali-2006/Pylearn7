# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("input\Bear.jpg",cv2.IMREAD_GRAYSCALE)
hist=cv2.calcHist([image],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()

# %%
image = cv2.imread("input\Lion.jpg",cv2.IMREAD_GRAYSCALE)
hist=cv2.calcHist([image],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()
a=2

# %%
print("Hello Note Book")

# %%
image = cv2.imread("input\House.png",cv2.IMREAD_GRAYSCALE)
hist=cv2.calcHist([image],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()

# %%
image_low_contrast = cv2.imread("input\PgaNb.png",cv2.IMREAD_GRAYSCALE)
hist=cv2.calcHist([image_low_contrast],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()

# %%
image_high_contrast = cv2.equalizeHist(image_low_contrast)
cv2.imwrite("output\Result11.jpg",image_high_contrast)
hist=cv2.calcHist([image_high_contrast],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()
