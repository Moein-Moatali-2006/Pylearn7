# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("RGB.png")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
# result_0 = image[: , : , 0]
# result_1 = image[: , : , 1]
# result_2 = image[: , : , 2]
# cv2.imwrite("result_0.png",result_0)
# cv2.imwrite("result_1.png",result_1)
# cv2.imwrite("result_2.png",result_2)

# %%
plt.imshow(image)
